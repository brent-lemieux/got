# %% [markdown]
# ## Likely
#
# * Cersei Lannister -
# * Jaime Lannister
#
# * Tormund Giantsbane
# * Beric Dondarrion
# * Eddison Tollett
#
# * Thoros of Myr
#
# * Euron Greyjoy
#
# * Petyr "Littlefinger" Baelish
#
# * Bronn
#
# * Sandor "The Hound" Clegane
# * Gregor Clegane
#
# * Nymeria Sand - 2
# * Yara Greyjoy - 2
# * Tyene Sand - 2
#
# * Qyburn

# %% [markdown]
# ## Maybe
# * Davos Seaworth
# * Brienne of Tarth
# * Jorah Mormont
# * Grey Worm
# * Meera Reed
# * Podrick Payne
# * Ellaria Sand

# %% [markdown]
# ## Unlikely
# * Jon Snow
# * Daenerys Targaryen
# * Melisandre
# * Sansa Stark
# * Missandei
# * Arya Stark
# * Varys
# * Theon Greyjoy
# * Samwell Tarly
# * Gilly
# * Bran Stark
# * the Night King
# * Tyrion Lannister
# * Olenna Tyrell
# * Lyanna Mormont

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/got_deaths.csv')

# %%
df.head().T
# Out:
#                                                             0  \
# name                                                     Will
# role                               Ranger of the Nights Watch
# death_season                                                1
# death_episode                                               1
# execution                 Beheaded for desertion by Ned Stark
# likelihoodofreturn                                          0
# likelihoodofreturn_notes                                  NaN
# deathflashback                                            NaN
#
#                                                                 1  \
# name                                                    Jon Arryn
# role                            Hand to the King before Ned Stark
# death_season                                                    1
# death_episode                                                   1
# execution                 Poisoned by Lysa Arryn and Littlefinger
# likelihoodofreturn                                              0
# likelihoodofreturn_notes                                      NaN
# deathflashback                                                NaN
#
#                                                                    2  \
# name                                                     Jory Cassel
# role                            Captain of the guards to House Stark
# death_season                                                       1
# death_episode                                                      5
# execution                 Stabbed by Jaime Lannister through the eye
# likelihoodofreturn                                                 0
# likelihoodofreturn_notes                                         NaN
# deathflashback                                                   NaN
#
#                                                                           3  \
# name                                                      Viserys Targaryen
# role                      Exiled head of House Targaryen and brother to ...
# death_season                                                              1
# death_episode                                                             6
# execution                 Khal Drogo pours molten gold on his head at Da...
# likelihoodofreturn                                                        0
# likelihoodofreturn_notes                                                NaN
# deathflashback                                                          NaN
#
#                                                                           4
# name                                                           Benjen Stark
# role                      First Ranger of the Nights Watch, Brother of N...
# death_season                                                              1
# death_episode                                                             7
# execution                                                           Unknown
# likelihoodofreturn                                                     0.15
# likelihoodofreturn_notes  He could have survived all this time or become...
# deathflashback                                                          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
# name                        100 non-null object
# role                        100 non-null object
# death_season                100 non-null int64
# death_episode               100 non-null int64
# execution                   100 non-null object
# likelihoodofreturn          100 non-null float64
# likelihoodofreturn_notes    13 non-null object
# deathflashback              2 non-null object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.3+ KB

# %%
by_ep = df.groupby('death_episode', as_index=False)['name'].count()
by_ep
# Out:
#    death_episode  name
# 0              1     7
# 1              2     8
# 2              3     6
# 3              4     6
# 4              5     9
# 5              6     4
# 6              7     6
# 7              8     8
# 8              9    17
# 9             10    29

# %%
by_seas = df.groupby(['death_season', 'death_episode'], as_index=False)['name'].count()
by_seas.columns = ['death_season', 'death_episode', 'death_count']
by_seas
# Out:
#     death_season  death_episode  death_count
# 0              1              1            2
# 1              1              5            1
# 2              1              6            1
# 3              1              7            2
# 4              1              8            1
# 5              1              9            1
# 6              1             10            3
# 7              2              2            1
# 8              2              3            1
# 9              2              5            1
# 10             2              6            1
# 11             2              7            1
# 12             2             10            5
# 13             3              3            1
# 14             3              4            3
# 15             3              5            1
# 16             3              6            1
# 17             3              9            3
# 18             4              1            1
# 19             4              2            2
# 20             4              5            3
# 21             4              7            1
# 22             4              8            2
# 23             4              9            5
# 24             4             10            3
# 25             5              1            1
# 26             5              3            1
# 27             5              4            1
# 28             5              7            1
# 29             5              8            1
# 30             5              9            2
# 31             5             10            6
# 32             6              1            3
# 33             6              2            5
# 34             6              3            3
# 35             6              4            2
# 36             6              5            3
# 37             6              6            1
# 38             6              7            1
# 39             6              8            4
# 40             6              9            6
# 41             6             10           12

# %%
plt.figure(figsize=(12,6))

for season in np.unique(by_seas['death_season']):
    seas_df = by_seas.loc[by_seas['death_season']==season]
    plt.plot(seas_df['death_episode'], seas_df['death_count'], label=season)
    plt.legend()
    
plt.xticks(list(range(11)))
plt.title('Death Episode by Season')
plt.savefig('images/death_episode_by_season.png')
plt.show()

# %%
names = df.name.tolist()

# %%
players = []

for name in names:
    check = input("Is this person a major player -- {}? [y/n]".format(name))
    if check == 'y':
        players.append(name)
    else:
        continue
# Out:
# Is this person a major player -- Will? [y/n]n
# Is this person a major player -- Jon Arryn? [y/n]n
# Is this person a major player -- Jory Cassel? [y/n]n
# Is this person a major player -- Viserys Targaryen? [y/n]y
# Is this person a major player -- Benjen Stark? [y/n]y
# Is this person a major player -- Robert Baratheon? [y/n]y
# Is this person a major player -- Syrio Forel? [y/n]n
# Is this person a major player -- Eddard Stark? [y/n]y
# Is this person a major player -- Drogo? [y/n]y
# Is this person a major player -- Rhaego? [y/n]n
# Is this person a major player -- Mirri Maz Duur? [y/n]n
# Is this person a major player -- Rakharo? [y/n]n
# Is this person a major player -- Yoren? [y/n]y
# Is this person a major player -- Renly Baratheon? [y/n]y
# Is this person a major player -- Rodrik Cassel? [y/n]n
# Is this person a major player -- Irri? [y/n]n
# Is this person a major player -- Maester Luwin? [y/n]y
# Is this person a major player -- Qhorin? [y/n]n
# Is this person a major player -- Pyat Pree? [y/n]n
# Is this person a major player -- Doreah? [y/n]n
# Is this person a major player -- Xaro Xhoan Daxos? [y/n]y
# Is this person a major player -- Hoster Tully? [y/n]n
# Is this person a major player -- Jeor Mormont? [y/n]y
# Is this person a major player -- Craster? [y/n]y
# Is this person a major player -- Kraznys? [y/n]n
# Is this person a major player -- Beric Dondarrion? [y/n]y
# Is this person a major player -- Ros? [y/n]n
# Is this person a major player -- Talisa Stark? [y/n]n
# Is this person a major player -- Robb Stark? [y/n]y
# Is this person a major player -- Catelyn Stark? [y/n]y
# Is this person a major player -- Polliver? [y/n]n
# Is this person a major player -- Tansy? [y/n]n
# Is this person a major player -- Joffrey Baratheon? [y/n]y
# Is this person a major player -- Karl Tanner? [y/n]n
# Is this person a major player -- Locke? [y/n]n
# Is this person a major player -- Rast? [y/n]n
# Is this person a major player -- Lysa Arryn? [y/n]y
# Is this person a major player -- Oberyn Martell? [y/n]y
# Is this person a major player -- The Mountain? [y/n]y
